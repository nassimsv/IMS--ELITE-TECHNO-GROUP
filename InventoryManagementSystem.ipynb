# %%
import datetime
import uuid 
from prettytable import PrettyTable
from datetime import date
import json

# %%
SelectedSection={1:"FreshProduce",2:"Bakery",3:"Chocolate",4:"Dairy",5:"Stationary"}
OutOfStock={}

# %%
def displayf(key):
    FileInventory=open("inventory.json",'r')
    inventoryjs=FileInventory.read()
    FileInventory.close()
    inventory=json.loads(inventoryjs)
    if(key==1):
        print("\n\n\n\n-------------------------------------------------------------FRESH PRODUCE--------------------------------------\n\n")
        dt = PrettyTable(['PID','Product Name'  , 'Section' ,    'Purchase Prize'  , 'Selling Prize', 'Qnty' , 'Shelf Life', 'Offer(%)' , 'T Quantity'])
        for items in inventory:
            if (inventory[items]['section']=="FreshProduce"):
                dt.add_row([items,inventory[items]["Name"],inventory[items]["section"], inventory[items]["PP"],inventory[items]["PricePerUnit"],inventory[items]["Units"],inventory[items]["ShelfLife"],
                           inventory[items]["Off"],inventory[items]["TQ"]])
                                     
        print(dt)
                
    elif(key==2):
        print("\n\n\n\n--------------------------------------------------------------BAKERY-------------------------------------------\n\n")
        dt = PrettyTable(['PID','Product Name'  , 'Section' ,    'Purchase Prize'  , 'Selling Prize', 'Qnty' , 'Shelf Life', 'Offer(%)' , 'T Quantity'])
        for items in inventory:
            if (inventory[items]['section']=="Bakery" ):
                dt.add_row([items,inventory[items]["Name"],inventory[items]["section"], inventory[items]["PP"],inventory[items]["PricePerUnit"],inventory[items]["Units"],inventory[items]["ShelfLife"],
                           inventory[items]["Off"],inventory[items]["TQ"]])
                                     
        print(dt)
    elif(key==3):
        print("\n\n\n\n------------------------------------------------------------CHOCOLATE-------------------------------------------\n\n")
        dt = PrettyTable(['ID','Product Name'  , 'Section' ,    'Purchase Prize'  , 'Selling Prize', 'Qnty' , 'Shelf Life', 'Offer(%)' , 'T Quantity'])
        for items in inventory:
            if (inventory[items]['section']=="Chocolate" ):
                dt.add_row([items,inventory[items]["Name"],inventory[items]["section"], inventory[items]["PP"],inventory[items]["PricePerUnit"],inventory[items]["Units"],inventory[items]["ShelfLife"],
                           inventory[items]["Off"],inventory[items]["TQ"]])
                                     
        print(dt)
    elif(key==4):
        print("\n\n\n\n-------------------------------------------------------------DAIRY-------------------------------------------\n\n")
        dt = PrettyTable(['PID','Product Name'  , 'Section' ,    'Purchase Prize'  , 'Selling Prize', 'Qnty' , 'Shelf Life', 'Offer(%)' , 'T Quantity'])
        for items in inventory:
            if (inventory[items]['section']=="Dairy" ):
                dt.add_row([items,inventory[items]["Name"],inventory[items]["section"], inventory[items]["PP"],inventory[items]["PricePerUnit"],inventory[items]["Units"],inventory[items]["ShelfLife"],
                           inventory[items]["Off"],inventory[items]["TQ"]])
                                     
        print(dt)
    elif(key==5):
        print("\n\n\n\n----------------------------------------------------------STATIONARY-------------------------------------------\n\n")
        dt = PrettyTable(['PID','Product Name'  , 'Section' ,    'Purchase Prize'  , 'Selling Prize', 'Qnty' , 'Offer(%)' , 'T Quantity'])
        for items in inventory:
            if (inventory[items]['section']=="Stationary" ):
                dt.add_row([items,inventory[items]["Name"],inventory[items]["section"], inventory[items]["PP"],inventory[items]["PricePerUnit"],inventory[items]["Units"],
                           inventory[items]["Off"],inventory[items]["TQ"]])
                                     
        print(dt)

# %%
UnitsSold={}
Pivoice={}
Sinvoice={}

# %%
choice=0
while(choice!=5):
   
    print("\n\n\n###################### INVENTORY MANAGER  ######################\n")
    print("1. DISPLAY and EDIT inventory (Purchase item/Remove item/Update item details) ")
    print("2. SELL ITEMS and INVOICE GENERATION")
    print("3. OUT OF STOCK ITEMS")
    print("4. SALES DETAILS")
    print("5. CLOSE \n")

    choice=int(input("ENTER YOUR CHOICE: "))
    if(choice==1):
        dchoice=0
        while(dchoice!=5): 
            print("\n\n\n###################### DISPLAY AND UPDATE INVENTORY ######################")
            print("1. Display Inventory ")
            print("2. Purchase Item to Inventory")
            print("3. Remove Item from Inventory")
            print("4. Update Item Details")
            print("5. Back")
            dchoice=int(input("ENTER YOUR CHOICE: "))
            
            if(dchoice==5):
                continue
            
            elif(dchoice==1):
                displayf(1)
                displayf(2)
                displayf(3)
                displayf(4)
                displayf(5)
             
            elif(dchoice==2):
                PurchasingList={}
                sec=0
                
                while(sec!=7):
                
                    print("\n###################################### PURCHASE SECTION ###################################\n")
                    print("\nEnter the section where product is to be purchased \n1.FreshProduce\n2.Bakery\n3.Chocolate\n4.Dairy\n5.Stationary\n6.Generate Invoice\n7.Back\n")
                    print("\n\n!!!!! GENERATE INVOICE FOR PURCHASE COMPLETION!!!!!!!!!!!\n\n")
                    sec=int(input("Enter your choice : "))
                    if(sec not in SelectedSection and sec!=6 and sec!=7):
                        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                        print("Invalid Input")
                        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                    elif(sec==6):
                        
                        if(len(PurchasingList)==0):
                            print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                            print("YOU HAVE NOT SELECTED ANY ITEM!!!!!!!!!!")
                            print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                        else:
                            FileInventory=open("inventory.json",'r')
                            inventoryjs=FileInventory.read()
                            FileInventory.close()
                            inventory=json.loads(inventoryjs)
                            sum=0
                            profit=0
                            print("\n\n\n============================================ PURCHASING INVOICE========================================================\n\n")
                            t = PrettyTable(['PID', 'Section' ,  'Product Name'  ,  'Prchs Prize'  , 'Sell Prize', 'Qnty' , 'Ttl Purchs Amnt' ,   'PROFIT(expected)'])
                            for items in PurchasingList:
                                if(items!="Date" and items!="Profit" and items!="Total"):
                                    t.add_row([items,inventory[items]["section"],inventory[items]["Name"], inventory[items]["PP"],inventory[items]["PricePerUnit"],PurchasingList[items],inventory[items]["PP"]*PurchasingList[items],((inventory[items]["PricePerUnit"]-(inventory[items]["PricePerUnit"]*inventory[items]["Off"]/100))*
                                          PurchasingList[items])-((inventory[items]["PP"]*PurchasingList[items]))])
                                    sum=sum+((inventory[items]["PP"]*PurchasingList[items]))
                                    profit=profit+ (((inventory[items]["PricePerUnit"]-(inventory[items]["PricePerUnit"]*inventory[items]["Off"]/100))*
                                      PurchasingList[items]))-((inventory[items]["PP"]*PurchasingList[items]))  
                            print(t)
                            print("\n\n\nTOTAL PURCHASE AMOUNT="+str(sum))
                            print("PROFIT EXPECTED="+str(profit))
                            PurchasingList["Profit"]=profit
                            PurchasingList["Total"]=sum
                            SalesPurchase=open("SalesPurchase.json",'r')
                            SPjs=SalesPurchase.read()
                            SalesPurchase.close()
                            Pinvoice=json.loads(SPjs)
                            TID=input("\n\nEnter unique transaction id for the invoice generated: ")
                            while(TID in Pinvoice):
                                TID=input("ID EXIST!!!!!!!!! Enter unique ID: ")
                            Pinvoice[TID]=PurchasingList
                            SPjs=json.dumps(Pinvoice)
                            SalesPurchase=open("SalesPurchase.json",'w')
                            
                            SalesPurchase.write(SPjs)
                            SalesPurchase.close()
                            sec=7
                            print("\n=======================================================================================================================\n\n")
                            continue
                    elif(sec==7):
                        continue
                    elif(sec in SelectedSection): 
                        FileInventory=open("inventory.json",'r')
                        inventoryjs=FileInventory.read()
                        FileInventory.close()
                        inventory=json.loads(inventoryjs)
                        today=date.today()
                        d = today.strftime("%Y-%m-%d")
                        PurchasingList["Date"]=d
                        
                        displayf(sec)
                        ID=input("\n\nEnter the product ID of the item to be inserted to the inventory\n")
                        if(ID not in inventory):
                        
                            N=input("Enter Product Name: ")
                            PP=int(input("Enter purchase prize of the product: "))
                            P=int(input("Enter Selling prize per unit: "))
                            U=int(input("Enter number of units to be purchased: "))
                            O=int(input("Enter offer for the product: "))
                            T=int(input("Enter Threshold quantity: "))
                            
                            if(sec!=5):
                                S=input("Enter Shelf life of the product (YYYY-MM-DD) :")
                                inventory[ID]={"Name":N,"section":SelectedSection[sec],"PP":PP,"PricePerUnit":P,"Units":U,"ShelfLife":S,"Off":O,"TQ":T}
                                if (U<=T):
                                    OutOfStock[ID]=U
                                PurchasingList[ID]=U
                                inventoryjs=json.dumps(inventory)
                                FileInventory=open("inventory.json",'w')
                                FileInventory.write(inventoryjs)
                                FileInventory.close()
                                print("==================================== SUCCESSFULLY PURCHASED =====================================")
                                
                               
                        
                            else:
                                inventory[ID]={"Name":N,"section":"Stationary","PP":PP,"PricePerUnit":P,"Units":U,"Off":O,"TQ":T}
                                if (U<=T):
                                    OutOfStock[ID]=U
                                PurchasingList[ID]=U
                                inventoryjs=json.dumps(inventory)
                                FileInventory=open("inventory.json",'w')
                                FileInventory.write(inventoryjs)
                                FileInventory.close()
                                print("==================================== SUCCESSFULLY PURCHASED =====================================")
                                
                        else:
                            
                            if(ID in PurchasingList):
                                print(inventory[ID]["Name"]+" already exist in purchase list")
                                inventory[ID]["Units"]=inventory[ID]["Units"]-PurchasingList[ID]
                                U=int(input("Enter total no of units to be purchased: "))
                                PurchasingList[ID]=U
                                inventory[ID]["Units"]=inventory[ID]["Units"]+PurchasingList[ID]
                                inventoryjs=json.dumps(inventory)
                                FileInventory=open("inventory.json",'w')
                                FileInventory.write(inventoryjs)
                                FileInventory.close()
                                print("\n==================================== SUCCESSFULLY PURCHASED =====================================")
                                continue
                            
                                
                                
                        
                            if(inventory[ID]["section"]=="Stationary"):
                                
                                print("\n\n"+inventory[ID]["Name"]+" already exist in inventory, The purchase prize of the existing product is "+str(inventory[ID]["PP"]))
                                print("\n\n1. Purchase Prize of the product changed\n2. Purchase prize is the same")
                                a=int(input("Enter your chice: "))
                                if (a==2):
                                    if(ID in PurchasingList):
                                        print(inventory[ID]["Name"]+" already exist in purchase list")
                                        inventory[ID]["Units"]=inventory[ID]["Units"]-PurchasingList[ID]
                                        
                                        U=int(input("Enter total no of units to be purchased: "))
                                        PurchasingList[ID]=U
                                        inventory[ID]["Units"]=inventory[ID]["Units"]+PurchasingList[ID]
                                    else:
                                        U=int(input("Enter number of units to be purchased:"))
                                        inventory[ID]["Units"]=U+inventory[ID]["Units"]
                                        if (inventory[ID]["Units"]<=inventory[ID]["TQ"]):
                                            OutOfStock[ID]=inventory[ID]["Units"]
                                        else:
                                            if(ID in OutOfStock):
                                                del OutOfStock[ID]
                                        PurchasingList[ID]=U
                                    inventoryjs=json.dumps(inventory)
                                    FileInventory=open("inventory.json",'w')
                                    FileInventory.write(inventoryjs)
                                    FileInventory.close()
                                    print("==================================== SUCCESSFULLY PURCHASED =====================================")
                                    
                                elif(a==1):
                                    print("\n\nYou have to insert the product with new product ID\n")
                                    NI=input("NEW PRODUCT ID: ")
                                    while(NI in inventory):
                                        print("Product ID already exist enter unique product ID: ")
                                        NI=input("NEW PRODUCT ID: ")
                                        
                                    N=input("Enter Product Name: ")
                                    PP=int(input("Enter new purchase prize of the product: "))
                                    P=int(input("Enter new selling prize per unit: "))
                                    U=int(input("Enter number of units to be purchased: "))
                                    O=int(input("Enter offer for the product: "))
                                    T=int(input("Enter Threshold quantity: "))
                                    inventory[NI]={"Name":N,"section":"Stationary","PP":PP,"PricePerUnit":P,"Units":U,"Off":O,"TQ":T}
                                    if (U<=T):
                                        OutOfStock[NI]=U
                                    PurchasingList[NI]=U
                                    inventoryjs=json.dumps(inventory)
                                    FileInventory=open("inventory.json",'w')
                                    FileInventory.write(inventoryjs)
                                    FileInventory.close()
                                    print("==================================== SUCCESSFULLY PURCHASED =====================================")
                                    
                                else:
                                    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                                    print("Invalid Input")
                                    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                       
                                    
                            else:
                                if(ID in PurchasingList):
                                    print(inventory[ID]["Name"]+" already exist in purchase list")
                                    inventory[ID]["Units"]=inventory[ID]["Units"]-PurchasingList[ID]
                                    U=int(input("Enter total no of units to be purchased: "))
                                    PurchasingList[ID]=U
                                    inventory[ID]["Units"]=inventory[ID]["Units"]+PurchasingList[ID]
                                    inventoryjs=json.dumps(inventory)
                                    FileInventory=open("inventory.json",'w')
                                    FileInventory.write(inventoryjs)
                                    FileInventory.close()
                                    print("\n==================================== SUCCESSFULLY PURCHASED =====================================")
                                    continue
                               
                                print("\n\n"+inventory[ID]["Name"]+" already exist in inventory, with shelf life of "+inventory[ID]["ShelfLife"]+" and selling prize "+str((inventory[ID]["PricePerUnit"])-(inventory[ID]["Off"]/100*inventory[ID]["PricePerUnit"])))
                                print("\nTherefore you have to enter the currently purchasing product as NEW PRODUCT")
                                NI=input("NEW PRODUCT ID: ")

                                    
                                while(NI in inventory):
                                    
                                    print("Product ID already exist enter unique product ID: ")
                                    NI=input("NEW PRODUCT ID: ")
                                    
                                N=input("Enter Product Name: ")
                                PP=int(input("Enter purchase prize of the product: "))
                                P=int(input("Enter selling prize per unit: "))
                                U=int(input("Enter number of units to be purchased: "))
                                O=int(input("Enter offer for the product: "))
                                T=int(input("Enter Threshold quantity: "))
                                S=input("Enter Shelf life of the product (YYYY-MM-DD) : ")
                                inventory[NI]={"Name":N,"section":SelectedSection[sec],"PP":PP,"PricePerUnit":P,"Units":U,"ShelfLife":S,"Off":O,"TQ":T}
                                if (U<=T):
                                    OutOfStock[NI]=U
                                PurchasingList[NI]=U
                                inventoryjs=json.dumps(inventory)
                                FileInventory=open("inventory.json",'w')
                                FileInventory.write(inventoryjs)
                                FileInventory.close()
                                print("==================================== SUCCESSFULLY PURCHASED =====================================")
                                
                    else:
                        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                        print("Invalid Input")
                        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                        
                                
                                
                        
                            
                        
                        
            elif(dchoice==3):
                print("\n\n###################################### REMOVE ITEM ###################################")
                print("\n\nEnter the section of product which is to be removed \n1.FreshProduce\n2.Bakery\n3.Chocolate\n4.Dairy\n5.Stationary\n")
                sec=int(input())
                if(sec not in SelectedSection):
                    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                    print("Invalid Input")
                    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                else:
                    FileInventory=open("inventory.json",'r')
                    inventoryjs=FileInventory.read()
                    FileInventory.close()
                    inventory=json.loads(inventoryjs)
                    displayf(sec)
                    ID=input("\n\nEnter the product ID of the item to be removed from the inventory\n")
                    if(ID not in inventory):
                        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                        print("ITEM DOESN'T EXIST IN INVENTORY")
                        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                    else:
                        del inventory[ID]
                        inventoryjs=json.dumps(inventory)
                        FileInventory=open("inventory.json",'w')
                        FileInventory.write(inventoryjs)
                        FileInventory.close()
                        print("=======================SUCCESSFULLY REMOVED============================")
                
            elif(dchoice==4):
                print("\n\n###################################### UPDATE SECTION ###################################")
                print("\n\nEnter the section of product which is to be updated \n1.FreshProduce\n2.Bakery\n3.Chocolate\n4.Dairy\n5.Stationary\n")
                sec=int(input())
                if(sec not in SelectedSection):
                    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                    print("Invalid Input")
                    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                else:   
                    displayf(sec)
                    FileInventory=open("inventory.json",'r')
                    inventoryjs=FileInventory.read()
                    FileInventory.close()
                    inventory=json.loads(inventoryjs)
                    ID=input("\n\nEnter the product ID of the item of which the details is to be updated\n")
                    if(ID not in inventory or inventory[ID]["section"]!=SelectedSection[sec]):
                        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                        print("INVALID PRODUCT ID")
                        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                    else:
                        print("\n\n########################### "+inventory[ID]["Name"]+" UPDATE SECTION #################################\n\n" )
                        print("1.Update Prize per Unit of "+ inventory[ID]["Name"])
                        print("2.Update Offer of "+ inventory[ID]["Name"])
                        print("3.Update Threshold quantity of "+ inventory[ID]["Name"])
                        if(inventory[ID]["section"]!="Stationary"):
                            print("4.Update Shelflife of "+ inventory[ID]["Name"])
                            print("5.Back")
                        else:
                            print("4.Back")
                        c=int(input("Enter your choice:"))
                        while(((c!=5)and(inventory[ID]["section"]!="Stationary" )) or ((c!=4)and(inventory[ID]["section"]=="Stationary" ))): 
                            
                            if(c==4 and inventory[ID]["section"]=="Stationary" ):
                                continue
                            if(c==5 and inventory[ID]["section"]!="Stationary" ):
                                continue
                            if(c==4 and inventory[ID]["section"]!="Stationary"):
                                inventory[ID]["ShelfLife"]=input("Enter shelflife (YYYY-MM-DD) :")
                                inventoryjs=json.dumps(inventory)
                                FileInventory=open("inventory.json",'w')
                                FileInventory.write(inventoryjs)
                                FileInventory.close()
                                print("\n========================Successfully Updated============================")
                                print("\n\n########################### "+inventory[ID]["Name"]+" UPDATE SECTION #################################\n\n" )
                                print("1.Update Prize per Unit of "+ inventory[ID]["Name"])
                                print("2.Update Offer of "+ inventory[ID]["Name"])
                                print("3.Update Threshold quantity of "+ inventory[ID]["Name"])
                                if(inventory[ID]["section"]!="Stationary"):
                                    print("4.Update Shelflife of "+ inventory[ID]["Name"])
                                    print("5.Back")
                                else:
                                    print("4.Back")
                                c=int(input("Enter your choice:"))
                                continue
                            if(c==3):
                                inventory[ID]["TQ"]=int(input("Enter Threshold quantity:"))
                                if(inventory[ID]["Units"]<=inventory[ID]["TQ"]):
                                    OutOfStock[ID]=inventory[ID]["Units"]
                                else:
                                    if(ID in OutOfStock):
                                        del OutOfStock[ID]
                                inventoryjs=json.dumps(inventory)
                                FileInventory=open("inventory.json",'w')
                                FileInventory.write(inventoryjs)
                                FileInventory.close()
                                print("\n========================Successfully Updated============================")
                            elif(c==2):
                                inventory[ID]["Off"]=int(input("Enter new Off:"))
                                inventoryjs=json.dumps(inventory)
                                FileInventory=open("inventory.json",'w')
                                FileInventory.write(inventoryjs)
                                FileInventory.close()
                                print("\n========================Successfully Updated============================")
                            elif(c==1):

                                inventory[ID]["PricePerUnit"]=int(input("Enter Price Per Unit:"))
                                inventoryjs=json.dumps(inventory)
                                FileInventory=open("inventory.json",'w')
                                FileInventory.write(inventoryjs)
                                FileInventory.close()
                                print("\n========================Successfully Updated============================")
                            else:
                                print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                                print("Invalid Input")
                                print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                            print("\n\n########################### "+inventory[ID]["Name"]+" UPDATE SECTION #################################\n\n" )
                            print("1.Update Prize per Unit of "+ inventory[ID]["Name"])
                            print("2.Update Offer of "+ inventory[ID]["Name"])
                            print("3.Update Threshold quantity of "+ inventory[ID]["Name"])
                            if(inventory[ID]["section"]!="Stationary"):
                                print("4.Update Shelflife of "+ inventory[ID]["Name"])
                                print("5.Back")
                            else:
                                print("4.Back")
                            c=int(input("Enter your choice:"))
                        
            else:
                print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                print("Invalid Input")
                print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")          
                    
          
           
    elif(choice==2):
        SellingList={}
        key=0
        while(key!=7):
            print("\n\n\n###################### SELLING SECTION ######################")
            print("1.Fresh Produce\n2.Bakery\n3.Chocolate\n4.Dairy\n5.Stationary\n6.Gnerate Invoice\n7.Back\n\n\n")
            print("\n\n!!!!!!!!!!!!!!!! Generate invoice for succesfull selling!!!!!!!!!!!!!!!!")
            key=int(input("Input Selling Section:"))
            if(key==6):
                if(len(SellingList)==0):
                    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                    print("YOU HAVE NOT SELECTED ANY ITEM!!!!!!!!!!")
                    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                else:
                    FileInventory=open("inventory.json",'r')
                    inventoryjs=FileInventory.read()
                    FileInventory.close()
                    inventory=json.loads(inventoryjs)
                    sum=0
                    print("\n\n\n============================================ SELLING INVOICE========================================================\n\n")
                    
                    st = PrettyTable(['PID', 'Section' ,  'Product Name'  ,  'Selling Prize'  ,  'Qnty' , 'Offer' ,   'Discount','Payable Amnt'])
                    for items in SellingList:
                        if(items!="Date" and items!="Total" and items!="TID"):
                            st.add_row([items,inventory[items]["section"],inventory[items]["Name"], inventory[items]["PricePerUnit"],SellingList[items],inventory[items]["Off"],(inventory[items]["PricePerUnit"]*inventory[items]["Off"]/100)*SellingList[items],
                                         (inventory[items]["PricePerUnit"]-(inventory[items]["PricePerUnit"]*inventory[items]["Off"]/100))*SellingList[items] ])
                            sum=sum+(inventory[items]["PricePerUnit"]-(inventory[items]["PricePerUnit"]*inventory[items]["Off"]/100))*SellingList[items]
                    print(st)
                    print("\n\n\n\nTOTAL AMOUNT="+str(sum))
                    
                    SellingList["Total"]=sum
                    SalesSold=open("SalesSold.json",'r')
                    SSjs=SalesSold.read()
                    SalesSold.close()
                    Sinvoice=json.loads(SSjs)
                    TID=input("\n\nEnter unique transaction id for the invoice generated: ")
                    while(TID in Sinvoice):
                        TID=input("ID EXIST!!!!!!!!!!!! Enter unique ID: ")
                    Sinvoice[TID]=SellingList
                    SSjs=json.dumps(Sinvoice)
                    SalesSold=open("SalesSold.json",'w')
                    SalesSold.write(SSjs)
                    SalesSold.close()
                    key=7
                    print("\n=======================================================================================================================\n\n")
                    continue
                    


            elif(key==7):
                continue
                
            elif(key==1 or key==2 or key==3 or key==4 or key==5):
                displayf(key)
                today=date.today()
                d = today.strftime("%Y-%m-%d")
                SellingList["Date"]=d
                FileInventory=open("inventory.json",'r')
                inventoryjs=FileInventory.read()
                FileInventory.close()
                inventory=json.loads(inventoryjs)
                print("__________________________________________________________________________________________")
                print("\n\n-Enter product ID and No.of units to be sold (separate them with hyphen(-))")
                print("-Press ENTER key to input next item")
                print("-Enter 'FINISH' if all the products are entered\n\n")
                PIDs="START"
                while(PIDs!="FINISH"):
                    PIDs=input("Enter PID-Quantity / FINISH: ")
                    if(PIDs=="FINISH"):
                        continue
                    if("-" not in PIDs):
                        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                        print("\nINVALID\n")
                        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                        continue
                    else:
                        item,quantity=PIDs.split("-")
                        if(item not in inventory or inventory[item]["section"]!=SelectedSection[key]):
                            print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                            print("\nINVALID PRODUCT ID\n")
                            print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                        else:
                            if(item in SellingList):
                                
                                inventory[item]["Units"]=inventory[item]["Units"]+SellingList[item]
                                del SellingList[item]
                                if(int(quantity)!=0):
                                    print("Item already exist, Enter the total quantity required")
                                    quantity=int(input("Total "+inventory[item]["Name"]+" required:"))
                                else:
                                    print(inventory[item]["Name"]+" REMOVED FROM THE CART")
                                    continue
                            if(int(quantity)>inventory[item]["Units"]):
                                print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                                print("\nThere are only "+ str(inventory[item]["Units"])+ " units available!!!!!!\n")
                                print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                            else:
                                inventory[item]["Units"]=inventory[item]["Units"]-int(quantity)
                                SellingList[item]=int(quantity)
                                if(inventory[item]["Units"]<=inventory[item]["TQ"]):
                                    OutOfStock[item]=inventory[item]["Units"]
                                inventoryjs=json.dumps(inventory)
                                FileInventory=open("inventory.json",'w')
                                FileInventory.write(inventoryjs)
                                FileInventory.close()
                                print("==============================SUCCESSFULLY ADDED TO CART=============================")
                                print("\n\nYOU can remove the item by entering 'PID-0' (removes product with id PID from the cart)")
            else:
                print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                print("\nENTER VALID CHOICE\n")
                print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                        
                
                    
    elif(choice==4):
        sales=0
        FileInventory=open("inventory.json",'r')
        inventoryjs=FileInventory.read()
        FileInventory.close()
        inventory=json.loads(inventoryjs)
        while(sales!=3):
            print("\n\n1. Purchase details")
            print("2. Selling details")
            print("3. Back")
            sales=int(input("Enter your choice : "))
            if (sales==3):
                continue
            elif sales==2:
                print("Enter the time period of which the PURCHASE DETAILS is to be shown")
                date_entry = input('Enter first date in YYYY-MM-DD format: ')
                year, month, day = map(int, date_entry.split('-'))
                date1 = datetime.date(year, month, day)
                date_entry = input('Enter second date in YYYY-MM-DD format: ')
                year, month, day = map(int, date_entry.split('-'))
                date2 = datetime.date(year, month, day)
                
                SalesSold=open("SalesSold.json",'r')
                SSjs=SalesSold.read()
                SalesSold.close()
                Sinvoice=json.loads(SSjs)
                TOTAL=0
                for i in Sinvoice:
                    year, month, day = map(int, Sinvoice[i]["Date"].split('-'))
                    date=datetime.date(year, month, day)
                    if date1<=date<=date2:
                        print("\n\n\n============================================ SELLING INVOICE========================================================\n\n")
                        print("Transaction ID: "+ i)
                        st = PrettyTable(['PID', 'Section' ,  'Product Name'  ,  'Selling Prize'  ,  'Qnty' , 'Offer' ,   'Discount','Payable Amnt'])
                        for items in Sinvoice[i]:
                            if(items!="Date" and items!="Total" and items!="TID"):
                                st.add_row([items,
                                            inventory[items]["section"],
                                            inventory[items]["Name"],
                                            inventory[items]["PricePerUnit"],
                                            Sinvoice[i][items],
                                            inventory[items]["Off"],
                                            (inventory[items]["PricePerUnit"]*inventory[items]["Off"]/100),
                                            Sinvoice[i][items]*(inventory[items]["PricePerUnit"]-(inventory[items]["PricePerUnit"]*inventory[items]["Off"]/100))])
                                            
                                            
                        
                        TOTAL=TOTAL+Sinvoice[i]["Total"]
                        print(st)
                print("\n\nTotal amount received after selling : " + str(TOTAL))
                       
                        
                
                print("\n\nTOTAL EARNED="+str(TOTAL))
            elif sales==1:
                print("Enter the time period of which the PURCHASE DETAILS is to be shown")
                date_entry = input('Enter first date in YYYY-MM-DD format: ')
                year, month, day = map(int, date_entry.split('-'))
                date1 = datetime.date(year, month, day)
                date_entry = input('Enter second date in YYYY-MM-DD format: ')
                year, month, day = map(int, date_entry.split('-'))
                date2 = datetime.date(year, month, day)
                
                SalesPurchase=open("SalesPurchase.json",'r')
                SPjs=SalesPurchase.read()
                SalesPurchase.close()
                Pinvoice=json.loads(SPjs)
            
                PURCHASE=0
                PPRO=0
              
                for i in Pinvoice:
            
                    year, month, day = map(int, Pinvoice[i]["Date"].split('-'))
                    date=datetime.date(year, month, day)
                    if date1<=date<=date2:
                        
                        print("\n\n\n============================================ PURCHASING INVOICE========================================================\n\n")
                        print("\n\nTransaction ID: "+ i)
                        t = PrettyTable(['PID', 'Section' ,  'Product Name'  ,  'Prchs Prize'  , 'Sell Prize', 'Qnty' , 'Ttl Purchs Amnt' , 'PROFIT(expected)'])
                        for items in Pinvoice[i]:
                            if items!="Profit" and items!="Total" and items != "Date":
                                
                                t.add_row([items,
                                           inventory[items]["section"],
                                           inventory[items]["Name"],
                                           inventory[items]["PP"],
                                           inventory[items]["PricePerUnit"], 
                                           Pinvoice[i][items],
                                           inventory[items]["PP"]*Pinvoice[i][items],
                                           ((inventory[items]["PricePerUnit"]-(inventory[items]["PricePerUnit"]*inventory[items]["Off"]/100))* Pinvoice[i][items])-( inventory[items]["PP"]*Pinvoice[i][items])])
                            
                                           
                                           
                                           
                                           
                                                                                      

                                                    
                            
                        
                        PURCHASE=PURCHASE+Pinvoice[i]["Total"]
                        PPRO=PPRO+Pinvoice[i]["Profit"]
                        print(t)         
                print("\n\nTOTAL PURCHASE AMOUNT= "+str(PURCHASE))
                print("\nTOTAL PROFIT EXPECTED= "+str(PPRO))
                        
                            
                                
                        
                        
                        
                        
                
            else:
                print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                print("\nENTER VALID CHOICE\n")
                print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                    
                    
                
    elif(choice==5):
        continue
    else:
        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
        print("\nENTER VALID CHOICE\n")
        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
# Out:
# ###################### INVENTORY MANAGER  ######################
#
# 1. DISPLAY and EDIT inventory (Purchase item/Remove item/Update item details)
# 2. SELL ITEMS and INVOICE GENERATION
# 3. OUT OF STOCK ITEMS
# 4. SALES DETAILS
# 5. CLOSE
#
# ENTER YOUR CHOICE: 4
#
#
# 1. Purchase details
# 2. Selling details
# 3. Back
# Enter your choice : 2
# Enter the time period of which the PURCHASE DETAILS is to be shown
# Enter first date in YYYY-MM-DD format: 2000-12-12
# Enter second date in YYYY-MM-DD format: 2022-12-12
#
#
#
# ============================================ SELLING INVOICE========================================================
#
#
# Transaction ID: 123
# +------+--------------+--------------+---------------+------+-------+----------+--------------+
# | PID  |   Section    | Product Name | Selling Prize | Qnty | Offer | Discount | Payable Amnt |
# +------+--------------+--------------+---------------+------+-------+----------+--------------+
# ...
